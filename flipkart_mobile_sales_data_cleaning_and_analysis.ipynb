# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinesh-waran/Flipkart-mobile-datset-cleaning./blob/main/flipkart_mobile_sales_data_cleaning_and_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('Mobiles_Dataset.csv')
print(data)
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 979                        Kechaoda A27       ₹1,499           ₹967    4.0
# 980                        Kechaoda A27       ₹1,499           ₹975    4.0
# 981                        Kechaoda A27       ₹1,499           ₹975    4.0
# 982                        Kechaoda A27       ₹1,499           ₹930    4.0
# 983                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...

# %%
data.head()
# Out:
#                          Product Name Actual price Discount price  Stars  \
# 0     Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1      Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2     Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3  OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4  OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
#
#            Rating        Reviews RAM (GB) Storage (GB)  Display Size (inch)  \
# 0  44,793 Ratings  2,402 Reviews      NIL          128                 6.10
# 1  44,793 Ratings  2,402 Reviews      NIL          128                 6.10
# 2  44,793 Ratings  2,402 Reviews      NIL          128                 6.10
# 3   1,005 Ratings     41 Reviews        4          128                 6.56
# 4   1,005 Ratings     41 Reviews        4           64                 6.56
#
#         Camera                                        Description  \
# ...

# %%
data.tail()
# Out:
#      Product Name Actual price Discount price  Stars          Rating  \
# 979  Kechaoda A27       ₹1,499           ₹967    4.0  11,022 Ratings
# 980  Kechaoda A27       ₹1,499           ₹975    4.0  11,022 Ratings
# 981  Kechaoda A27       ₹1,499           ₹975    4.0  11,022 Ratings
# 982  Kechaoda A27       ₹1,499           ₹930    4.0  11,022 Ratings
# 983  Kechaoda A27       ₹1,499           ₹967    4.0  11,022 Ratings
#
#          Reviews RAM (GB) Storage (GB)  Display Size (inch)       Camera  \
# 979  693 Reviews      NIL          NIL                 0.66  0MP | 0MP
# 980  693 Reviews      NIL          NIL                 0.66          NaN
# 981  693 Reviews      NIL          NIL                 0.66          NaN
# 982  693 Reviews      NIL          NIL                 0.66  0MP | 0MP
# 983  693 Reviews      NIL          NIL                 0.66  0MP | 0MP
#
#                                            Description  \
# 979  32 MB RAM | 32 MB ROM | Expandable Upto 16 GB1...
# ...

# %%
print(data.shape)
# Out:
# (984, 12)

# %%
print(data.size)
# Out:
# 11808

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Product Name, Actual price, Discount price, Stars, Rating, Reviews, RAM (GB), Storage (GB), Display Size (inch), Camera, Description, Link]
# Index: []

# %%
data.drop_duplicates(inplace=True)
print(data.size)
# Out:
# 11808

# %%
data.isnull().sum()
# Out:
# Product Name            0
# Actual price            0
# Discount price          0
# Stars                   0
# Rating                  0
# Reviews                 0
# RAM (GB)                0
# Storage (GB)            0
# Display Size (inch)     0
# Camera                 76
# Description             0
# Link                    0
# dtype: int64

# %%
data=data.dropna()
data.isnull().sum()
# Out:
# Product Name           0
# Actual price           0
# Discount price         0
# Stars                  0
# Rating                 0
# Reviews                0
# RAM (GB)               0
# Storage (GB)           0
# Display Size (inch)    0
# Camera                 0
# Description            0
# Link                   0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 908 entries, 0 to 983
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         908 non-null    object
#  1   Actual price         908 non-null    object
#  2   Discount price       908 non-null    object
#  3   Stars                908 non-null    float64
#  4   Rating               908 non-null    object
#  5   Reviews              908 non-null    object
#  6   RAM (GB)             908 non-null    object
#  7   Storage (GB)         908 non-null    object
#  8   Display Size (inch)  908 non-null    float64
#  9   Camera               908 non-null    object
#  10  Description          908 non-null    object
#  11  Link                 908 non-null    object
# dtypes: float64(2), object(10)
# memory usage: 92.2+ KB

# %%
data["Stars"]
# Out:
# 0      4.6
# 1      4.6
# 2      4.6
# 3      4.0
# 4      4.0
#       ...
# 977    4.1
# 978    4.0
# 979    4.0
# 982    4.0
# 983    4.0
# Name: Stars, Length: 908, dtype: float64

# %%
data[data["Product Name"].str.contains("Apple")]
# Out:
#                                  Product Name Actual price Discount price  \
# 0             Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999
# 1              Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999
# 2             Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999
# 28      Apple iPhone 15 Plus (Yellow, 128 GB)      ₹89,600        ₹73,999
# 156     Apple iPhone 14 Plus (Purple, 512 GB)    ₹1,09,600        ₹86,499
# 257    Apple iPhone 14 ((PRODUCT)RED, 128 GB)      ₹69,600        ₹59,999
# 401       Apple iPhone 14 (Starlight, 128 GB)      ₹69,600        ₹59,999
# 453  Apple iPhone 14 Plus (Starlight, 128 GB)      ₹79,600        ₹56,499
# 492           Apple iPhone 15 (Green, 256 GB)      ₹89,600        ₹75,999
# 493           Apple iPhone 15 (Green, 256 GB)      ₹89,600        ₹75,999
# 581           Apple iPhone 15 (Black, 256 GB)      ₹89,600        ₹75,999
# 582           Apple iPhone 15 (Black, 256 GB)      ₹89,600        ₹75,999
# ...

# %%
data[data["Product Name"].str.contains("OnePlus")]
# Out:
#                                           Product Name Actual price  \
# 3                   OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999
# 4                   OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999
# 5                      OnePlus 12R (Cool Blue, 128 GB)      ₹39,999
# 19                    OnePlus 12 (Silky Black, 512 GB)      ₹69,999
# 20                    OnePlus 12 (Silky Black, 512 GB)      ₹69,999
# 30            OnePlus 11R 5G (Galactic Silver, 128 GB)      ₹39,999
# 87   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...      ₹21,999
# 131                 OnePlus 12 (Flowy Emerald, 512 GB)      ₹69,999
# 149    OnePlus Nord CE4 lite 5G (SUPER SILVER, 256 GB)      ₹23,999
# 217                 OnePlus 12 (Flowy Emerald, 256 GB)      ₹64,999
# 262                    OnePlus 12R (Cool Blue, 256 GB)      ₹45,999
# 269                 OnePlus 12 (Glacial White, 256 GB)      ₹64,999
# 283                    OnePlus 12R (Iron Gray, 128 GB)          NIL
# ...

# %%
data[data["Product Name"].str.contains("vivo")]
# Out:
#                               Product Name Actual price Discount price  Stars  \
# 9    vivo Y200e 5G (Black Diamond, 128 GB)      ₹25,999        ₹20,999    4.3
# 10   vivo Y200e 5G (Black Diamond, 128 GB)      ₹23,999        ₹19,999    4.2
# 61   vivo Y200 Pro 5G (Silk Green, 128 GB)          NIL        ₹24,999    4.2
# 62   vivo Y200 Pro 5G (Silk Green, 128 GB)          NIL        ₹24,999    4.2
# 67      vivo Y28 5G (Glitter Aqua, 128 GB)      ₹21,999        ₹16,999    4.3
# ..                                     ...          ...            ...    ...
# 899  vivo T2x 5G (Sunstone Orange, 128 GB)      ₹17,999        ₹13,678    4.4
# 900  vivo T2x 5G (Sunstone Orange, 128 GB)          NIL        ₹18,999    4.4
# 918         vivo Y18e (Space Black, 64 GB)      ₹11,999         ₹8,689    4.1
# 955   vivo X70 Pro+ (Enigma Black, 256 GB)      ₹84,990        ₹48,999    4.5
# 956   vivo X70 Pro+ (Enigma Black, 256 GB)      ₹84,990        ₹48,999    4.5
#
# ...

# %%
data[data["Product Name"].str.contains("Motorola")]
# Out:
#                                           Product Name Actual price  \
# 12                Motorola G85 5G (Urban Grey, 128 GB)      ₹20,999
# 13                Motorola G85 5G (Urban Grey, 128 GB)      ₹20,999
# 14                   Motorola g04s (Satin Blue, 64 GB)       ₹9,999
# 15                 Motorola g64 5G (Ice Lilac, 256 GB)      ₹19,999
# 118                Motorola G32 (Satin Maroon, 128 GB)      ₹18,999
# 220          Motorola Edge 40 Neo (Caneel Bay, 128 GB)      ₹27,999
# 264    Motorola Edge 50 Ultra 5G (Forest Grey, 512 GB)      ₹64,999
# 305                                       Motorola a10       ₹1,630
# 317        Motorola Edge 40 Neo (Black Beauty, 128 GB)      ₹27,999
# 335                 Motorola e13 (Cosmic Black, 64 GB)       ₹9,999
# 341    Motorola Edge 50 Ultra 5G (Nordic Wood, 512 GB)      ₹64,999
# 364              Motorola G34 5G (Ocean Green, 128 GB)      ₹14,999
# 365              Motorola G34 5G (Ocean Green, 128 GB)      ₹13,999
# ...

# %%
data[data["Product Name"].str.contains("Nokia")]
# Out:
#                                           Product Name Actual price  \
# 25                                           Nokia 105       ₹1,699
# 78   Nokia 105 Single SIM, Keypad Mobile Phone with...       ₹1,599
# 92   Nokia 106 4G Keypad Mobile, Long-Lasting Batte...       ₹2,999
# 219                     Nokia C32 (Beach Pink, 128 GB)      ₹10,999
# 288  Nokia 150 Dual Sim Keypad Phone, , Long Lastin...          NIL
# 289  Nokia 150 Dual Sim Keypad Phone, , Long Lastin...          NIL
# 293                    Nokia C32 (Breezy Mint, 128 GB)      ₹10,999
# 307  Nokia 105 Single SIM, Keypad Mobile Phone with...       ₹1,599
# 308  Nokia 5310 DS Keypad Mobile, FM Radio,Camera w...       ₹3,999
# 309  Nokia 5310 DS Keypad Mobile, FM Radio,Camera w...       ₹3,999
# 358                                       Nokia 105 DS       ₹1,499
# 471  Nokia 150 Dual Sim Keypad Phone, , Long Lastin...       ₹3,199
# 472  Nokia 150 Dual Sim Keypad Phone, , Long Lastin...       ₹3,199
# ...

# %%
data[data["Product Name"].str.contains("realme")]
# Out:
#                                     Product Name Actual price Discount price  \
# 22   realme 12 Pro+ 5G (Navigator Beige, 256 GB)      ₹37,999        ₹33,999
# 23   realme 12 Pro+ 5G (Navigator Beige, 256 GB)      ₹35,999        ₹31,999
# 24   realme 12 Pro+ 5G (Navigator Beige, 256 GB)      ₹35,999        ₹31,999
# 36      realme 13 Pro 5G (Emerald Green, 256 GB)      ₹30,999        ₹28,999
# 37      realme 13 Pro 5G (Emerald Green, 128 GB)      ₹28,999        ₹26,999
# ..                                           ...          ...            ...
# 906    realme 13 Pro+ 5G (Emerald Green, 512 GB)      ₹40,999        ₹36,999
# 907    realme 13 Pro+ 5G (Emerald Green, 256 GB)      ₹38,999        ₹34,999
# 934   realme NARZO 70X 5G (FOREST GREEN, 128 GB)      ₹17,999        ₹12,872
# 935   realme NARZO 70X 5G (FOREST GREEN, 128 GB)      ₹16,999        ₹12,300
# 936   realme NARZO 70X 5G (FOREST GREEN, 128 GB)      ₹16,999        ₹12,488
#
# ...

# %%
data[data["Product Name"].str.contains("Infinix")]
# Out:
#                                          Product Name Actual price  \
# 26             Infinix SMART 8 HD (Shiny Gold, 64 GB)       ₹7,999
# 27             Infinix SMART 8 HD (Shiny Gold, 64 GB)       ₹8,999
# 76              Infinix SMART 8 (Rainbow Blue, 64 GB)       ₹8,999
# 77             Infinix SMART 8 (Rainbow Blue, 128 GB)      ₹10,999
# 93             Infinix HOT 30i (Glacier Blue, 128 GB)          NIL
# 96            Infinix HOT 40i (Starlit Black, 256 GB)      ₹10,999
# 153       Infinix Note 40 Pro 5G (Titan Gold, 256 GB)      ₹27,999
# 276            Infinix HOT 40i (Horizon Gold, 256 GB)      ₹10,999
# 282            Infinix GT 20 Pro (Mecha Blue, 256 GB)      ₹34,999
# 290         Infinix SMART 8 HD (Crystal Green, 64 GB)       ₹7,999
# 291         Infinix SMART 8 HD (Crystal Green, 64 GB)       ₹8,999
# 319   Infinix Note 40 Pro+ 5G (Vintage Green, 256 GB)      ₹32,999
# 329          Infinix Zero 30 5G (Golden Hour, 256 GB)      ₹27,999
# ...

# %%
data[data["Product Name"].str.contains("itel")]
# Out:
#                                           Product Name Actual price  \
# 21   itel it5027 6.1cm Screen,1200mAh Battery Wirel...       ₹1,499
# 33   itel A70 | 5000 mAh Battery |13MP Dual  | Type...       ₹7,299
# 56   itel Aura 05i|Leather Finish|4000 Mah Battery|...       ₹6,799
# 103                    itel A05s (Meadow Green, 64 GB)       ₹6,999
# 139                                        itel it5262       ₹1,599
# 142  itel Aura 05i|Leather Finish|4000 Mah Battery|...       ₹6,799
# 166                      itel A70 (Azure Blue, 256 GB)      ₹10,999
# 170  itel P55 5G |50MP Dual |5000mAh Battery|Expand...      ₹12,999
# 189  itel A70 | 5000 mAh Battery |13MP Dual  | Type...       ₹7,299
# 190  itel A70 | 5000 mAh Battery |13MP Dual  | Type...       ₹7,299
# 191                  itel A70 (Briiliant Gold, 256 GB)      ₹10,999
# 206                                         itel ACE 2       ₹1,199
# 258                     itel P55 (Aurora Blue, 128 GB)       ₹9,999
# ...

# %%
data[data["Product Name"].str.contains("Tecno")]
# Out:
#                                       Product Name Actual price  \
# 29             Tecno Spark Go 2023 (Orange, 64 GB)       ₹9,999
# 60      Tecno Spark 20C (Magic Skin Green, 128 GB)      ₹10,499
# 63      Tecno Spark 20 Pro 5G (Neon Green, 128 GB)      ₹19,999
# 74   Tecno Spark Go 2024 (Magic Skin Green, 64 GB)       ₹7,499
# 75    Tecno Pova 5 Pro 5G (Silver Fantasy, 256 GB)      ₹20,999
# 163     Tecno Spark 10 (Magic Skin Orange, 128 GB)      ₹13,499
# 171        Tecno Spark 20C (Mystery White, 128 GB)      ₹10,499
# 232     Tecno Spark 10 Pro (Lunar Eclipse, 128 GB)      ₹13,999
# 294    Tecno POVA 5 Pro 5G (Dark Illusion, 256 GB)      ₹20,999
# 295    Tecno POVA 5 Pro 5G (Dark Illusion, 256 GB)      ₹20,999
# 306      Tecno Pova 6 Pro (Meteorite Grey, 256 GB)      ₹24,999
# 458         Tecno Spark 10 5G (Meta Black, 128 GB)      ₹15,999
# 470         Tecno Pova 6 Pro (Comet Green, 256 GB)      ₹24,999
# 503         Tecno Camon 20 (Serenity Blue, 256 GB)      ₹17,999
# ...

# %%
data[data["Product Name"].str.contains("SAMSUNG")]
# Out:
#                                           Product Name Actual price  \
# 6           SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)      ₹17,490
# 39   SAMSUNG Galaxy S24 Ultra 5G (Titanium Black, 2...    ₹1,34,999
# 53          SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)      ₹17,990
# 54          SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)      ₹17,990
# 55          SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)      ₹18,990
# ..                                                 ...          ...
# 902            SAMSUNG Galaxy F04 (Jade Purple, 64 GB)      ₹11,499
# 915   SAMSUNG Galaxy A54 5G (Awesome Graphite, 256 GB)      ₹45,999
# 923         SAMSUNG Galaxy M14 5G (ICY Silver, 128 GB)      ₹17,990
# 924         SAMSUNG Galaxy M14 5G (ICY Silver, 128 GB)      ₹17,990
# 964                 SAMSUNG Galaxy A03s (Black, 32 GB)      ₹13,499
#
#     Discount price  Stars            Rating        Reviews RAM (GB)  \
# 6          ₹10,990    4.2    45,538 Ratings  2,989 Reviews        4
# ...

# %%
data[data["Product Name"].str.contains("REDMI")]
# Out:
#                                       Product Name Actual price  \
# 68    REDMI Note 13 Pro+ 5G (Fusion Black, 512 GB)      ₹37,999
# 69    REDMI Note 13 Pro+ 5G (Fusion Black, 256 GB)      ₹33,999
# 70    REDMI Note 13 Pro+ 5G (Fusion Black, 256 GB)      ₹33,999
# 71    REDMI Note 13 Pro+ 5G (Fusion Black, 256 GB)      ₹33,999
# 72    REDMI Note 13 Pro+ 5G (Fusion Black, 256 GB)      ₹33,999
# ..                                             ...          ...
# 928  REDMI Note 13 Pro 5G (Midnight Black, 256 GB)      ₹30,999
# 929  REDMI Note 13 Pro 5G (Midnight Black, 128 GB)      ₹28,999
# 930  REDMI Note 13 Pro 5G (Midnight Black, 256 GB)      ₹32,999
# 931  REDMI Note 13 Pro 5G (Midnight Black, 256 GB)      ₹32,999
# 939       REDMI Note 12 5G (Mystique Blue, 256 GB)      ₹23,999
#
#     Discount price  Stars          Rating        Reviews RAM (GB)  \
# 68         ₹32,856    4.2   5,823 Ratings    587 Reviews       12
# ...

# %%
data[data["Product Name"].str.contains("LAVA")]
# Out:
#                                           Product Name Actual price  \
# 35   LAVA A3 Vibe DS Keypad Mobile| 1750 mAh Batter...       ₹1,649
# 59   LAVA A1 Josh BOL Keypad Mobile|1000 mAh Batter...       ₹1,399
# 89   LAVA Hero Shakti Keypad Mobile|1.8 inch Big Di...       ₹1,199
# 90   LAVA Hero Shakti Keypad Mobile|1.8 inch Big Di...       ₹1,199
# 140  LAVA A7 Torch Dual Sim Keypad Phone| 2574 mAh ...       ₹1,899
# 141  LAVA A7 Torch Dual Sim Keypad Phone| 2574 mAh ...       ₹1,899
# 194  LAVA Blaze Pro 5G with Dual Sim|50MP |5000 mAh...      ₹14,999
# 198  LAVA Gem Power Dual Sim Keypad Phone|2575 mAh ...       ₹2,099
# 199  LAVA Gem Power Dual Sim Keypad Phone|2575 mAh ...       ₹2,099
# 205                  LAVA O2 (Majestic Purple, 128 GB)       ₹9,999
# 214  LAVA Blaze 2 5G with Dual Sim|50MP |5000 mAh B...      ₹12,499
# 215  LAVA Blaze 2 5G with Dual Sim|50MP |5000 mAh B...      ₹12,499
# 222                       LAVA O2 (Royal Gold, 128 GB)      ₹11,999
# ...

# %%
data[data["Product Name"].str.contains("POCO")]
# Out:
#                              Product Name Actual price Discount price  Stars  \
# 41   POCO X6 5G (Snowstorm White, 512 GB)      ₹27,999        ₹21,999    4.3
# 42   POCO X6 5G (Snowstorm White, 256 GB)      ₹24,999        ₹18,999    4.2
# 43   POCO X6 5G (Snowstorm White, 256 GB)      ₹24,999        ₹18,999    4.2
# 44   POCO X6 5G (Snowstorm White, 256 GB)      ₹26,999        ₹20,999    4.3
# 48          POCO F6 5G (Titanium, 256 GB)      ₹33,999        ₹27,999    4.2
# ..                                    ...          ...            ...    ...
# 757        POCO C55 (Power Black, 128 GB)      ₹13,999        ₹10,999    4.2
# 762        POCO C65 (Pastel Blue, 128 GB)      ₹10,999         ₹6,999    4.3
# 763        POCO C65 (Pastel Blue, 128 GB)      ₹11,999         ₹7,499    4.2
# 764        POCO C65 (Pastel Blue, 256 GB)      ₹13,499         ₹9,499    4.2
# 944      POCO F4 5G (Night Black, 128 GB)      ₹32,999        ₹27,999    4.3
#
# ...

# %%
data[data["Product Name"].str.contains("IQOO")]
# Out:
#                                 Product Name Actual price Discount price  \
# 40        IQOO Z9 5G (Graphene Blue, 256 GB)      ₹26,999        ₹21,994
# 130  IQOO Neo9 Pro (Conqueror Black, 256 GB)      ₹44,999        ₹41,999
# 152            IQOO Z9X (Storm Grey, 128 GB)      ₹23,000        ₹15,910
# 243     IQOO Z7 Pro 5G (Blue Lagoon, 256 GB)      ₹27,999        ₹23,999
# 244     IQOO Z7 Pro 5G (Blue Lagoon, 128 GB)      ₹26,999        ₹22,999
# 256     IQOO Z9 Lite 5G (?Aqua Flow, 128 GB)      ₹14,499        ₹11,065
# 260            IQOO Z9x (Storm Grey, 128 GB)      ₹17,999        ₹13,200
# 261            IQOO Z9x (Storm Grey, 128 GB)      ₹17,999        ₹13,200
# 263      IQOO Z9 Lite 5G (Aqua Flow, 128 GB)      ₹15,499        ₹12,144
# 386    IQOO Z9 Lite 5G (Mocha Brown, 128 GB)      ₹14,499        ₹11,078
# 459         IQOO Z9X (Tornado Green, 128 GB)      ₹19,999        ₹15,916
# 486  IQOO Z7 Pro 5G (Graphite Matte, 256 GB)      ₹27,999        ₹23,999
# ...

# %%
data[data["Product Name"].str.contains("Nothing")]
# Out:
#                                      Product Name Actual price Discount price  \
# 7           CMF by Nothing Phone 1 (Blue, 128 GB)      ₹19,999        ₹15,999
# 8           CMF by Nothing Phone 1 (Blue, 128 GB)      ₹21,999        ₹17,999
# 17           Nothing Phone (2a) 5G (Blue, 128 GB)      ₹25,999        ₹23,999
# 18           Nothing Phone (2a) 5G (Blue, 256 GB)      ₹27,999        ₹25,999
# 165         Nothing Phone (2) (Dark Grey, 256 GB)      ₹54,999        ₹36,999
# 277         Nothing Phone (2a) 5G (White, 256 GB)      ₹29,999        ₹27,999
# 278         Nothing Phone (2a) 5G (White, 256 GB)      ₹27,999        ₹25,999
# 279         Nothing Phone (2a) 5G (White, 128 GB)      ₹25,999        ₹23,999
# 531             Nothing Phone (2) (White, 256 GB)      ₹54,999        ₹34,999
# 564        CMF by Nothing Phone 1 (Black, 128 GB)      ₹21,999        ₹17,999
# 565        CMF by Nothing Phone 1 (Black, 128 GB)      ₹19,999        ₹15,999
# ...

# %%
data[data["Product Name"].str.contains("CMF")]
# Out:
#                                      Product Name Actual price Discount price  \
# 7           CMF by Nothing Phone 1 (Blue, 128 GB)      ₹19,999        ₹15,999
# 8           CMF by Nothing Phone 1 (Blue, 128 GB)      ₹21,999        ₹17,999
# 564        CMF by Nothing Phone 1 (Black, 128 GB)      ₹21,999        ₹17,999
# 565        CMF by Nothing Phone 1 (Black, 128 GB)      ₹19,999        ₹15,999
# 793  CMF by Nothing Phone 1 (Light Green, 128 GB)      ₹21,999        ₹17,999
# 794  CMF by Nothing Phone 1 (Light Green, 128 GB)      ₹19,999        ₹15,999
#
#      Stars         Rating      Reviews RAM (GB) Storage (GB)  \
# 7      4.4  8,057 Ratings  701 Reviews        6          128
# 8      4.3  2,355 Ratings  181 Reviews        8          128
# 564    4.3  2,355 Ratings  181 Reviews        8          128
# 565    4.4  8,057 Ratings  701 Reviews        6          128
# 793    4.3  2,355 Ratings  181 Reviews        8          128
# ...

# %%
data[data["Product Name"].str.contains("Kechaoda")]
# Out:
#            Product Name Actual price Discount price  Stars          Rating  \
# 106       Kechaoda K115       ₹1,499         ₹1,060    4.1  35,912 Ratings
# 124         Kechaoda K9       ₹1,999         ₹1,165    4.1   3,157 Ratings
# 200  Kechaoda A26_black       ₹1,499           ₹999    4.0     484 Ratings
# 201  Kechaoda A26_black       ₹1,499           ₹999    4.0     484 Ratings
# 275       Kechaoda K112       ₹1,799         ₹1,503    4.0  26,939 Ratings
# 323       Kechaoda K115       ₹1,499         ₹1,060    4.1  35,912 Ratings
# 965       Kechaoda K112       ₹1,999         ₹1,525    4.0  26,939 Ratings
# 966       Kechaoda K112       ₹1,999         ₹1,525    4.0  26,939 Ratings
# 971        Kechaoda K33       ₹1,412         ₹1,064    4.0   9,879 Ratings
# 972        Kechaoda K33       ₹1,412         ₹1,064    4.0   9,879 Ratings
# 973        Kechaoda K28       ₹1,399         ₹1,260    4.0   4,073 Ratings
# ...

# %%
data.groupby('Link').Link.count()
# Out:
# Link
# https://www.flipkart.com/apple-iphone-12-black-256-gb/p/itm68421fa1c1121?pid=MOBFWBYZ7CR9FRHZ&lid=LSTMOBFWBYZ7CR9FRHZNVRHNR&marketplace=FLIPKART&q=mobile&store=tyy%2F4io&srno=s_35_825&otracker=AS_Query_OrganicAutoSuggest_4_2_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_4_2_na_na_na&fm=organic&iid=9770f813-48da-4cd7-939f-911b29e051b0.MOBFWBYZ7CR9FRHZ.SEARCH&ppt=None&ppn=None&ssid=p7kf2ktvow0000001722741186057&qH=532c28d5412dd75b          1
# https://www.flipkart.com/apple-iphone-12-black-64-gb/p/itma2559422bf7c7?pid=MOBFWBYZU5FWK2VP&lid=LSTMOBFWBYZU5FWK2VPQTNJSG&marketplace=FLIPKART&q=mobile&store=tyy%2F4io&srno=s_7_157&otracker=AS_Query_OrganicAutoSuggest_4_2_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_4_2_na_na_na&fm=organic&iid=b13a7f2f-baa5-4eef-bddf-f36e83d99894.MOBFWBYZU5FWK2VP.SEARCH&ppt=None&ppn=None&ssid=70sb7vkybk0000001722740569300&qH=532c28d5412dd75b            1
# ...

# %%
data['Rating'].unique()
# Out:
# array(['44,793 Ratings', '1,005 Ratings', '4,278 Ratings',
#        '45,538 Ratings', '8,057 Ratings', '2,355 Ratings', '687 Ratings',
#        '267 Ratings', '3,629 Ratings', '9,300 Ratings', '9,349 Ratings',
#        '12,943 Ratings', '13,911 Ratings', '40,281 Ratings',
#        '881 Ratings', '466 Ratings', '5,815 Ratings', '17,356 Ratings',
#        '753 Ratings', '33,838 Ratings', '810 Ratings', '7,658 Ratings',
#        '380 Ratings', '8,230 Ratings', '15,052 Ratings', '1,356 Ratings',
#        '357 Ratings', '1,536 Ratings', '54 Ratings', '4 Ratings',
#        '1,896 Ratings', '1,767 Ratings', '3,602 Ratings',
#        '12,632 Ratings', '22,564 Ratings', '11,376 Ratings',
#        '2,043 Ratings', '1,456 Ratings', '570 Ratings', '212 Ratings',
#        '6,481 Ratings', '24,580 Ratings', '727 Ratings', '1,046 Ratings',
#        '7,129 Ratings', '74 Ratings', '102 Ratings', '40 Ratings',
#        '1,274 Ratings', '243 Ratings', '5,823 Ratings', '7,528 Ratings',
# ...

# %%
data[(data['RAM (GB)']=="512") & (data['Stars']=="4.5")].count()
# Out:
# Product Name           0
# Actual price           0
# Discount price         0
# Stars                  0
# Rating                 0
# Reviews                0
# RAM (GB)               0
# Storage (GB)           0
# Display Size (inch)    0
# Camera                 0
# Description            0
# Link                   0
# dtype: int64

# %%
print(data)
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 979                        Kechaoda A27       ₹1,499           ₹967    4.0
# 980                        Kechaoda A27       ₹1,499           ₹975    4.0
# 981                        Kechaoda A27       ₹1,499           ₹975    4.0
# 982                        Kechaoda A27       ₹1,499           ₹930    4.0
# 983                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...
